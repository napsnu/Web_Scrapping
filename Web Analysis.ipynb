# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\code\python\books.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                  Title Star Rating  Price
# 0           0                   A Light in the Attic       Three  51.77
# 1           1                     Tipping the Velvet         One  53.74
# 2           2                             Soumission         One  50.10
# 3           3                          Sharp Objects        Four  47.82
# 4           4  Sapiens: A Brief History of Humankind        Five  54.23

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Title          0
# Star Rating    0
# Price          0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0      Price
# count     80.0000  80.000000
# mean      39.5000  35.708375
# std       23.2379  14.196145
# min        0.0000  12.840000
# 25%       19.7500  22.575000
# 50%       39.5000  35.955000
# 75%       59.2500  50.142500
# max       79.0000  58.110000

# %%
fig,ax=plt.subplots(figsize=(8,8))
sns.displot(df.Title)
# Out:
# E:\Anaconda\Anaconda1\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu")
