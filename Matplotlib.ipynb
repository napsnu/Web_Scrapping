# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,8])
y=np.array([5,13])
plt.plot(x,y)
plt.show()

# %%
xpoints=np.array([1,5])
ypoints=np.array([5,10])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
x=np.array([3, 7, 9, 13])
y=np.array([9, 1, 50, 18])
plt.plot(x,y)
plt.show()

# %%
x=np.array([1, 2, 3, 4])
y=np.array([5, 9, 11, 14])
plt.plot(x,y)
plt.show()

# %%
y=np.array([3, 8, 1, 10, 5, 7])
plt.plot(y)
plt.show()

# %%
x=np.array([0,1,2,3,4,5])
y=np.array([3, 8, 1, 10, 5, 7])
plt.plot(x,y,marker='x')
plt.show()

# %%
x=np.array([0,1,2,3,4,5])
y=np.array([3, 8, 1, 10, 5, 7])
plt.plot(x,y,linestyle='dotted')
plt.show()

# %%
x=np.array([0,1,2,3,4,5])
y=np.array([3, 8, 1, 10, 5, 7])
plt.plot(x,y,marker='p',linestyle='dotted')
plt.show()

# %%
x=np.array([1, 2, 3, 4])
y=np.array([5, 9, 11, 14])
plt.plot(x,y,color='red')
plt.show()

# %%
x=np.array([0,1,2,3,4,5])
y=np.array([3, 8, 1, 10, 5, 7])
plt.plot(x,y,marker='p',linestyle='dotted',color='yellow')
plt.show()

# %%
x=np.array([1, 2, 3, 4])
y=np.array([5, 9, 11, 14])
plt.plot(x,y,linewidth='15')
plt.show()

# %%
x1=np.array([1,5,7,9])
x2=np.array([10,1,20,5])
plt.plot(x1)
plt.plot(x2)
plt.show()

# %%
x1=np.array([1, 2, 3, 4])
x2=np.array([5, 9, 11, 14])
y1=np.array([1,6,8,10])
y2=np.array([6,3,6,9])
plt.plot(x1,x2,y1,y2)
plt.show()

# %%
x=np.array([1, 2, 3, 4])
y=np.array([5, 9, 11, 14])
plt.title("Student marks")
plt.xlabel("marks")
plt.ylabel("score")
plt.plot(x,y)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([10,20,30,40])
plt.plot(x,y)
plt.grid()
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([10,20,30,40])
plt.plot(x,y)
plt.grid(axis='y')
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([10,20,30,40])
plt.plot(x,y)
plt.grid(axis='x',color='red')
plt.show()

# %%
x=np.array([2,5,9,13])
y=np.array([9,1,3,6])
plt.subplot()
plt.show()

# %%
# import matplotlib.pyplot as plt

# Set the starting point P
P = [2, 3]

# Set the vector v
v = [3, 1]

# Add the coordinates of P to the vector v
v_plot = [v[0] + P[0], v[1] + P[1]]

# Plot the vector v starting from P
plt.quiver([P[0]], [P[1]], [v[0]], [v[1]], angles='xy', scale_units='xy', scale=1, color='blue')
plt.xlim([0, 7])
plt.ylim([0, 7])
plt.show()
